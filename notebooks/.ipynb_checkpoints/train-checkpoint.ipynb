# %%
from pathlib import Path

# %%
DATASET_ROOT = Path("/mnt/d/DataSets/Flickr8k")
IMAGES_DIR = DATASET_ROOT / "Flickr8k_Dataset"
TEXT_DIR = DATASET_ROOT / "Flickr8k_text"
CAPTIONS_FILE = TEXT_DIR / "Flickr8k.token.txt"

# %%
captions_by_image = {}

with CAPTIONS_FILE.open(encoding="utf-8") as file:
    for line in file:
        caption_id, caption = line.rstrip("\r\n").split("\t", maxsplit=1)
        image_name, _ = caption_id.rsplit("#", maxsplit=1)

        if image_name not in captions_by_image:
            captions_by_image[image_name] = []

        captions_by_image[image_name].append(caption)

train_images = (TEXT_DIR / "Flickr_8k.trainImages.txt").read_text().splitlines()
val_images = (TEXT_DIR / "Flickr_8k.devImages.txt").read_text().splitlines()
test_images = (TEXT_DIR / "Flickr_8k.testImages.txt").read_text().splitlines()

print(len(train_images), len(val_images), len(test_images))
# Out:
# 6000 1000 1000
